# %%
list = [
  "Icreativez Technologies",
  "Microsoft",
  "Apple",
  "Nvidia",
  "TSMC",
  "Broadcom",
  "ASML",
  "Samsung",
  "Oracle",
  "AMD",
  "Adobe",
  "Salesforce",
  "SAP",
  "Qualcomm",
  "Applied Materials",
  "Cisco",
  "Accenture",
  "Intuit",
  "Texas Instruments",
  "IBM",
  "Alphabet (Google)",
  "Amazon Web Services (AWS)",
  "Meta Platforms (Facebook)",
  "Alibaba",
  "Tencent",
  "Intel",
  "Dell Technologies",
  "VMware",
  "Zoom Video Communications",
  "Uber Technologies",
  "HP Inc.",
  "Oracle",
  "PayPal",
  "Shopify",
  "LinkedIn",
  "Slack",
  "Baidu",
  "Xiaomi",
  "Nvidia",
  "TCS (Tata Consultancy Services)",
  "Wipro",
  "Infosys",
  "Cognizant",
  "Atlassian",
  "ServiceNow",
  "Square (Block)",
  "Spotify",
  "TikTok (ByteDance)",
  "Hulu",
  "Roblox",
  "Dropbox",
  "Zendesk",
  "Box",
  "Smartsheet",
  "Asana",
  "Monday",
  "Airtable",
  "Figma",
  "Unity Technologies",
  "Epic Games",
  "Electronic Arts (EA)",
  "Autodesk",
  "Red Hat (IBM)",
  "Mimecast",
  "CrowdStrike",
  "Zscaler",
  "Sophos",
  "Canon",
  "Logitech",
  "GoDaddy",
  "Notion Labs",
  "Zscaler",
  "Proofpoint",
  "CyberArk",
  "Fortinet",
  "Dell Technologies",
  "VMware",
  "TikTok (ByteDance)",
  "Salesforce",
  "IBM",
  "Tableau Software",
  "Airtable",
  "Trello",
  "Atlassian",
  "Basecamp",
  "Monday",
  "Figma",
  "Freshworks",
  "Zoho",
  "HubSpot",
  "Palantir Technologies",
  "Snowflake",
  "Elastic",
  "Datadog",
  "Slack (Salesforce)",
  "Stripe",
  "Square (Block)",
  "Autodesk",
  "Epic Games",
  "Nintendo"
]
list

# %% [markdown]
# #amazon
# https://www.linkedin.com/jobs/search/?currentJobId=4166985450&distance=25.0&f_C=1586&f_TPR=r604800&geoId=103644278&keywords=Job%20Title%22%20(e.g.%2C%20%22Software%20Engineer%22)%20AND%20(%22Fortune%20500%22%20OR%20%22Global%20100%22%20OR%20%22Top%20Tech%20Companies%22)&origin=JOB_SEARCH_PAGE_JOB_FILTER&refresh=true
#
# https://www.linkedin.com/jobs/search/?currentJobId=4156607052&distance=25&f_C=1441&f_TPR=r604800&geoId=103644278&keywords=Software%20Engineer&origin=JOB_SEARCH_PAGE_JOB_FILTER&refresh=true

# %%
class Node:
    def __init__(self, val=0, next=None, prev=None):
        self.val = val
        self.next = next
        self.prev = prev
    
class LRUCache:

    def __init__(self, capacity: int):
        self.size = capacity
        self.head = Node()
        self.tail = Node()
        self.mdict = {}

    def get(self, key: int) -> int:
        

    def put(self, key: int, value: int) -> None:
        if key not in self.mdict:
            

# Your LRUCache object will be instantiated and called as such:
# obj = LRUCache(capacity)
# param_1 = obj.get(key)
# obj.put(key,value)

# 1 2 3 4 5; -> 3 remove 3 instantly
